# %%
from pyspark.sql import SparkSession
spark = SparkSession\
        .builder\
        .enableHiveSupport() \
        .appName("PythonWordCount")\
        .getOrCreate()

# %%
from pyspark.ml.feature import PCA
from pyspark.ml.linalg import Vectors
# $example off$


df = spark.read.csv("D:\RomiCode\DataScience\Datasets\soc_gen_data\\train.csv",header=True,inferSchema=True)
df.show()
#df.head()


#pca = PCA(k=3, inputCol="features", outputCol="pcaFeatures")
#pca = PCA(k=3, inputCol=df[0], outputCol="pcaFeatures")
#model = pca.fit(df)

#result = model.transform(df).select("pcaFeatures")
#result.show(truncate=False)
# Out:
# +----+-----------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-------+-----------+-----------+-----------+-----------+-----------+------
# ...

# %%
#https://www.analyticsvidhya.com/blog/2016/03/practical-guide-principal-component-analysis-python/
import numpy as np
import pandas as pd

from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
# %matplotlib inline

#Load data set
data = pd.read_csv('D:\RomiCode\DataScience\Datasets\soc_gen_data\\train.csv')
#data = pd.read_csv('D:\RomiCode\DataScience\Datasets\world-food-facts\FoodFacts.csv')

#convert it to numpy arrays

# %%
X=data.values  # convert the data into numpy array

#Scaling the values  - get teh variables on same range
X = scale(X)

pcamodel = PCA(n_components=102)

pcamodel.fit(X)
# Out:
# PCA(copy=True, n_components=102, whiten=False)

# %%
#The amount of variance that each PC explains
var= pcamodel.explained_variance_ratio_
print(var)

print(pcamodel.components_)


plt.plot(var1)
# Out:
# [  5.02587364e-01   1.71998226e-01   1.23812098e-01   4.15153732e-02
#    3.30043664e-02   1.95885492e-02   1.14859313e-02   1.04844686e-02
#    9.43124323e-03   8.12755742e-03   7.28354152e-03   6.21316433e-03
#    5.68876069e-03   4.94958943e-03   4.32031771e-03   3.90106288e-03
#    3.10898779e-03   2.75111775e-03   2.31685245e-03   2.13768497e-03
#    1.83767315e-03   1.64623022e-03   1.50772974e-03   1.41640859e-03
#    1.25472924e-03   1.16600972e-03   9.58310194e-04   8.99267708e-04
#    8.12233328e-04   7.73482712e-04   7.17361951e-04   7.03225503e-04
#    6.57083143e-04   6.33432767e-04   5.90316869e-04   5.69366868e-04
#    4.91905464e-04   4.57515326e-04   4.48537007e-04   4.24935573e-04
#    4.13644766e-04   3.84341283e-04   3.60349527e-04   3.20544227e-04
#    3.02221963e-04   2.92797992e-04   2.79334512e-04   2.70007029e-04
#    2.41456796e-04   2.15018903e-04   2.10279653e-04   2.03186495e-04
#    2.00140840e-04   1.88320846e-04   1.74033245e-04   1.68028110e-04
# ...

# %%
#Cumulative Variance explains
var1=np.cumsum(np.round(pcamodel.explained_variance_ratio_, decimals=4)*100)

#plt.plot(var)
print (var1)

plt.plot(var1)
# Out:
# [ 50.26  67.46  79.84  83.99  87.29  89.25  90.4   91.45  92.39  93.2
#   93.93  94.55  95.12  95.61  96.04  96.43  96.74  97.02  97.25  97.46
#   97.64  97.8   97.95  98.09  98.22  98.34  98.44  98.53  98.61  98.69
#   98.76  98.83  98.9   98.96  99.02  99.08  99.13  99.18  99.22  99.26
#   99.3   99.34  99.38  99.41  99.44  99.47  99.5   99.53  99.55  99.57
#   99.59  99.61  99.63  99.65  99.67  99.69  99.71  99.73  99.74  99.75
#   99.76  99.77  99.78  99.79  99.8   99.81  99.82  99.83  99.84  99.85
#   99.86  99.87  99.88  99.89  99.9   99.91  99.92  99.93  99.94  99.95
#   99.96  99.97  99.98  99.98  99.98  99.98  99.98  99.98  99.98  99.98
#   99.98  99.98  99.98  99.98  99.98  99.98  99.98  99.98  99.98  99.98
#   99.98  99.98]

# %%
data.columns
# Out:
# Index(['Time', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        ...
#        'X92', 'X93', 'X94', 'X95', 'X96', 'X97', 'X98', 'X99', 'X100', 'Y'],
#       dtype='object', length=102)

# %%
#Looking at above plot I'm taking 30 variables
pca = PCA(n_components=20)
pca.fit(X)
X1=pca.fit_transform(X)

print (X1)

# %%
from sklearn import tree

# %%
import pandas as pd

# %%
sc.appName
# Out:
# 'PySparkShell'

# %%
sc.environment
# Out:
# {}

# %%
sc.sparkHome

# %%
sc.sparkUser
# Out:
# <bound method SparkContext.sparkUser of <pyspark.context.SparkContext object at 0x0000000002C5B668>>

# %%
sqlcontext= SQLContext(sc)

# %%
custdf = spark.read.csv("D:\RomiCode\DataScience\Datasets\\cust.csv",header=True,inferSchema=True)

# %%
custdf.toPandas().describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-9ebaa7569ede> in <module>()
# ----> 1 custdf.toPandas().describe()
#
# C:\Spark\python\pyspark\sql\dataframe.py in toPandas(self)
#    1574         """
#    1575         import pandas as pd
# -> 1576         return pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    1577
#    1578     ##########################################################################################
#
# C:\Spark\python\pyspark\sql\dataframe.py in collect(self)
#     390         with SCCallSiteSync(self._sc) as css:
#     391             port = self._jdf.collectToPython()
# --> 392         return list(_load_from_socket(port, BatchedSerializer(PickleSerializer())))
#     393
#     394     @ignore_unicode_prefix
#
# C:\Spark\python\pyspark\rdd.py in _load_from_socket(port, serializer)
#     138     try:
# ...
